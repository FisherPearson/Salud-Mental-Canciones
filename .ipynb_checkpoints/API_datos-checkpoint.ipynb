# %%
import pandas as pd
from pandas import json_normalize
import requests
import json
from datetime import datetime
from datetime import timezone
import re 
from unidecode import unidecode

"INTEGRAR API SPOTIFY"

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# %% [markdown]
# <h1><center>DESCARGA TU PROPIA INFORMACIÓN</center></h1>

# %% [markdown]
# En este Notebook podrás descargar tu información spotify para su posterior análisis. Recuerda que, para poder utilizar estas credenciales, es necesario que previamente te comuniques con el autor para recibir los permisos para ejecutarla. En caso de que poseas credenciales propias para poder acceder a la API de spotify, puedes modificar el código para que funcione directamente con ellas[1].
#
# Se han incluido algunas otras métricas de interés que podrían resultar en un análisis más robusto de la persona. Son varias las herramientas estadísticas para poder analizar este tipo de valores contínuos y nomináles. Dado que el proyecto está orientado al análisis de textos, __solamente se hará uso del nombre del autor y del nombre de la canción__.
#
# Se utiliza la API [Lyrics OVH](https://lyricsovh.docs.apiary.io/#) para la obtención de la letra de cada canción. Es de uso libre y gratuíto.
#
#
#
# [1]: Desafortunadamente no se me concedió el permiso.

# %% [markdown]
# # Credenciales
#
# El proyecto está resguardado en un repositorio propio del autor. Por lo tanto, es necesario que pidas permiso para ser agregado a este. La única modificación que necesitas realizar es en el campo `username`.
#
# __NOTA__: Al pedir permiso envía al correo montanodavid780@gmail.com tu nombre de usuario de spotify y el correo con el que estás registrado.
#
# ![image.png](attachment:73b700d0-36d3-40ef-bb4f-cca361009de0.png)

# %%
cid = "dc74a8f0df534595ba93220a083618f2"
secret = "291e585936b946a89fdbffebfa2dff31" 
username = "p3zvjj8be7xofm13eqaiy5srh" # <---- Aquí introduce tu nombre de username
redirect_uri = "https://localhost:8080"

# %% [markdown]
# # Primer filtro (50 s - 120 s)

# %%
# %%time
scope = "user-top-read"
token = util.prompt_for_user_token(username,scope,cid,secret,redirect_uri)
sp = spotipy.Spotify(auth = token)


top = sp.current_user_top_tracks(time_range = "short_term", limit = 50)


indf_crudo = json_normalize(top["items"]).drop(columns = ["available_markets","disc_number","explicit","href","popularity","is_local","preview_url",
                                                   "track_number","uri","album.album_type","album.artists","type","album.available_markets",
                                                   "album.external_urls.spotify","album.href","album.id","album.images","album.release_date_precision",
                                                   "album.total_tracks","album.type","album.uri","external_ids.isrc","external_urls.spotify"])

artist = []
for i in range(indf_crudo.shape[0]):
    artist.append(indf_crudo["artists"][i][0]["name"])
    
indf = indf_crudo.copy()
indf["artists"] = artist

features = pd.DataFrame(indf["id"].apply(lambda x: sp.audio_features(x)[0]).to_list()).iloc[:,:13].drop(columns = "type")


base = pd.merge(indf,features, how = "left", on = "id")



def find_lyrics(df):
    dic = df[["artists","name"]].to_dict()
    
    artistas = dic["artists"]
    canciones = dic["name"]
    
    lyrics = []
    for i in range(df.shape[0]):
        autor = artistas[i]
        cancion = canciones[i]
        
        print(i)
        print(autor)
        print(cancion)
        print("---", 2*"\n")
        
        
        try:
            r = requests.get("https://api.lyrics.ovh/v1/{}/{}".format(autor,cancion))
            
            if "lyrics" in list(r.json().keys())[0]: 
                lyrics.append(r.json()["lyrics"])
            else:
                lyrics.append("")
        
        except:
            lyrics.append("error") 
            
    df["lyrics"] = lyrics
    
    

find_lyrics(base)
# Out:
# 0
# CKay
# love nwantiti (feat. Dj Yo! & AX'EL) - Remix
# ---
#
#
# 1
# J Balvin
# Si Tu Novio Te Deja Sola
# ---
#
#
# 2
# GIMS
# Reste
# ---
#
#
# 3
# Natalia Lafourcade
# Amor, Amor de Mis Amores (with Devendra Banhart)
# ---
#
#
# 4
# León Larregui
# Femme Fatal
# ---
#
#
# 5
# Queen
# Love Of My Life - Remastered 2011
# ---
#
#
# 6
# León Larregui
# Mar
# ---
#
#
# 7
# León Larregui
# Resguardum Ether
# ---
#
#
# 8
# Los Amigos Invisibles
# Viviré para Ti
# ---
#
#
# 9
# Natalia Lafourcade
# Soledad y el Mar (feat. Los Macorinos)
# ---
#
#
# 10
# Wisin
# Escápate Conmigo (feat. Ozuna)
# ---
#
#
# 11
# IAmChino
# Ay Mi Dios
# ---
#
#
# 12
# Arctic Monkeys
# Star Treatment
# ---
#
#
# 13
# Vaults
# One Last Night
# ---
#
#
# 14
# Pitbull
# Fireball (feat. John Ryan)
# ---
#
#
# 15
# Camilo
# Índigo
# ---
#
#
# 16
# Romeo Santos
# Yo También (feat. Marc Anthony)
# ---
#
#
# 17
# Grover Washington, Jr.
# Just the Two of Us
# ---
#
#
# 18
# Arctic Monkeys
# Tranquility Base Hotel & Casino
# ---
#
#
# 19
# Café Tacvba
# Avientame
# ---
#
#
# 20
# León Larregui
# Brillas - Love La Femme
# ---
#
#
# 21
# Julieta Venegas
# Lento
# ---
#
#
# 22
# Bee Gees
# More Than A Woman - From "Saturday Night Fever" Soundtrack
# ---
#
#
# 23
# Paulo Londra
# Adan y Eva
# ---
#
#
# 24
# Farruko
# Passion Whine
# ---
#
#
# 25
# Danny Ocean
# Dembow
# ---
#
#
# 26
# Mon Laferte
# Amor Completo
# ---
#
#
# 27
# Café Tacvba
# Una mañana - Unplugged
# ---
#
#
# 28
# Bee Gees
# Stayin Alive
# ---
#
#
# 29
# Jarabe De Palo
# La chica de Ipanema
# ---
#
#
# 30
# Bee Gees
# How Deep Is Your Love - From "Saturday Night Fever" Soundtrack
# ---
#
#
# 31
# Arctic Monkeys
# American Sports
# ---
#
#
# 32
# Arctic Monkeys
# One Point Perspective
# ---
#
#
# 33
# Arctic Monkeys
# Golden Trunks
# ---
#
#
# 34
# Tainy
# Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)
# ---
#
#
# 35
# Stacey Kent
# La vénus du mélo
# ---
#
#
# 36
# Bee Gees
# Night Fever - From "Saturday Night Fever" Soundtrack
# ---
#
#
# 37
# Los Amigos Invisibles
# La Que Me Gusta
# ---
#
#
# 38
# Zoé
# Poli / Love - En Vivo
# ---
#
#
# 39
# Los Amigos Invisibles
# Espérame Feat. Elastic Bond
# ---
#
#
# 40
# The Weeknd
# Out of Time
# ---
#
#
# 41
# J Balvin
# UN DIA (ONE DAY)
# ---
#
#
# 42
# J Balvin
# Sigo Extrañándote
# ---
#
#
# 43
# Mike Bahía
# Detente
# ---
#
#
# 44
# Pitbull
# We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] (feat. Jennifer Lopez & Claudia Leitte)
# ---
#
#
# 45
# CKay
# love nwantiti (ah ah ah)
# ---
#
#
# 46
# Vicente Garcia
# Carmesí
# ---
#
#
# 47
# Justin Bieber
# Get Me (feat. Kehlani)
# ---
#
#
# 48
# Lenny Kravitz
# It Ain't Over 'Til It's Over
# ---
#
#
# 49
# Café Tacvba
# Quiero Ver
# ---
#
#
# Wall time: 57 s

# %% [markdown]
# # Segundo filtro (15 s - 90 s)
#
# En ocasiones, algunos nombres de artístas o de canciones contienen carácteres que la API que provee las canciones no puede procesar. Es por eso que podría aplicarse un segundo filtro en caso de querer intentar nuevamente la busqueda pero aplicando una determinada limpieza en los nombres a fín de "robustecer" la base.

# %%
# %%time
try_base = base[(base["lyrics"] == "") | (base["lyrics"] == "error")].reset_index()

try_base.loc[try_base.name.str.extract(r"(.+(?=( -| \()))")[0].dropna().index,"name"] = try_base.name.str.extract(r"(.+(?=( -| \()))")[0].dropna() # Reemplaza los nombres

find_lyrics(try_base) # Encuentra canciones

try_base.set_index("index", inplace = True) # Regresa Indices originales

base.loc[try_base.index, ["name","lyrics"]] = try_base[["name","lyrics"]] # Pega a la base original

base["album.release_date"] = base["album.release_date"].apply(lambda x: x[:4]) # Extrae año
# Out:
# 0
# CKay
# love nwantiti (feat. Dj Yo! & AX'EL)
# ---
#
#
# 1
# GIMS
# Reste
# ---
#
#
# 2
# Natalia Lafourcade
# Amor, Amor de Mis Amores
# ---
#
#
# 3
# Queen
# Love Of My Life
# ---
#
#
# 4
# Los Amigos Invisibles
# Viviré para Ti
# ---
#
#
# 5
# Natalia Lafourcade
# Soledad y el Mar
# ---
#
#
# 6
# Grover Washington, Jr.
# Just the Two of Us
# ---
#
#
# 7
# Arctic Monkeys
# Tranquility Base Hotel & Casino
# ---
#
#
# 8
# León Larregui
# Brillas
# ---
#
#
# 9
# Bee Gees
# More Than A Woman
# ---
#
#
# 10
# Café Tacvba
# Una mañana
# ---
#
#
# 11
# Jarabe De Palo
# La chica de Ipanema
# ---
#
#
# 12
# Bee Gees
# How Deep Is Your Love
# ---
#
#
# 13
# Tainy
# Lo Siento BB:/
# ---
#
#
# 14
# Stacey Kent
# La vénus du mélo
# ---
#
#
# 15
# Bee Gees
# Night Fever
# ---
#
#
# 16
# Los Amigos Invisibles
# La Que Me Gusta
# ---
#
#
# 17
# Zoé
# Poli / Love
# ---
#
#
# 18
# Los Amigos Invisibles
# Espérame Feat. Elastic Bond
# ---
#
#
# 19
# The Weeknd
# Out of Time
# ---
#
#
# Wall time: 19 s

# %%
base
# Out:
#                    artists  duration_ms                      id  \
# 0                     CKay       188368  4gvrJnKCKIPiacNsWVQwEU
# 1                 J Balvin       243560  2joKSGkqac0LIwYG9Ghrwq
# 2                     GIMS       231520  0jaoiMgAKyCWR88qNUZt9T
# 37          0.000115    0.1350   0.5490  100.005
# 38          0.000014    0.7270   0.2520   91.299
# 39          0.000005    0.2070   0.7800  119.965
# 40          0.000000    0.3390   0.8380   93.057
# 41          0.000000    0.1740   0.4020  168.124
# 42          0.000115    0.2120   0.9380   93.016
# 43          0.000000    0.1060   0.3630  171.932
# 44          0.015400    0.1320   0.5670  125.013
# 45          0.001370    0.1610   0.5330   93.005
# 46          0.000224    0.1050   0.7320  121.968
# 47          0.000054    0.1070   0.7500  109.352
# 48          0.009280    0.3220   0.9300  159.690
# 49          0.000000    0.0750   0.3650  169.853
#
#                                                lyrics
# 0
# 1   J Balvin \nBad Bunny \nYo vivo día y noche pen...
# 2
# 3
# 4   Estrella fugas y algo desempatar \nel tiempo s...
# 5   Love of my life - you've hurt me\r\nYou've bro...
# 6   Bendito mar\r\nque limpias toda la maldad\r\nr...
# 7   Devoción como glándula de mi fe\r\nVoluntad mu...
# 8
# 9
# 10  Ozuna \nW \nSerá la magia que tienen tus ojos ...
# 11  Quizá se le olvido (Mr. WorldWide) \nQue los b...
# 12  I just wanted to be one of The Strokes\r\nNow ...
# 13  Tied to a sallow heart\r\nWhy does he want to ...
# 14  Mr. Worldwide to infinity\nYou know the roof o...
# 15  How can one dream\r\nWith someone you haven’t ...
# 16  ¿Quién eres tú?\r\nPara alardear y presumir me...
# 17
# 18
# 19  Abrázame y muerdeme, llévate contigo mis herid...
# 20  Nos dimos todo lo que se nos dio\r\nNos dimos ...
# 21  Si quieres un poco de mí,\r\nme deberías esper...
# 22  Oh, girl, I've known you very well. \nI've see...
# 23  O-O-Ovy On The Drums\r\nAcércate, deja la duda...
# 24  In Come Di Ting Dem a Call Passion It Wine For...
# 25  Acércarte que quiero decirte algo baby \nTengo...
# 26  No, no hay nada mejor\r\nque probar un primer ...
# 27  UNA MAÑANA\r\nUNA MAÑANA LINDA\r\nEL CORAZON C...
# 28  Well, you can tell by the way I use my walk, \...
# 29
# 30  I know your eyes in the morning sun.\r\nI feel...
# 31  My virtual reality mask is stuck on ‘Parliamen...
# 32  Dancing my underpants\r\nI'm gonna run for gov...
# 33  Last night when my psyche's subcommittee sang ...
# 34
# 35
# 36  Listen to the ground,\r\nthere is movement all...
# 37
# 38                                              error
# 39
# 40
# 41  You know that sometimes I think about us now a...
# 42  Tú sabes que no quiero perderte \nSabes que es...
# 43  ¿Dime qué haces aquí?\r\nCuando se suponía, qu...
# 44  Put your flags up in the sky (put them in the ...
# 45  Tu-tu-tu, tu-tu-tu-uh-tu-tu\r\nUh-tu-tu-tu, tu...
# 46  Vida que ha venido \nPa' llenarme de color el ...
# 47  Oh, you don't compare, don't fit in with 'em, ...
# 48  here we are still together\r\nwe are one\r\nso...
# 49  Quiero ver\r\ntu risa todo el dia\r\nescuchar ...

# %% [markdown]
# ---

# %% [markdown]
# # Guarda tu base en formato CSV

# %%
tu_nombre = "Aquí escribe tu primer nombre en minúsculas" # david
#base.to_csv(f"top_{tu_nombre}_spotify.csv")
